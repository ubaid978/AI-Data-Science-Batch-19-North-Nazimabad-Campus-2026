# %% [markdown]
# # Variables

# %%
38
# Out:
# 38

# %%
'matric'
# Out:
# 'matric'

# %% [markdown]
# ## what is varaibales ?
#
# In Python, a variable is a named container or symbolic name that points to a specific value or object stored in your computer's memory. You use them to store, modify, and retrieve data dynamically throughout your program
#
#
# ## Structure :
#
#      variable_name=value

# %%
10
# Out:
# 10

# %%
a=10

# %%
a
# Out:
# 10

# %%
a
# Out:
# 10

# %%
a
# Out:
# 10

# %%
name='ali'
age=18
weight=55
height=5.6

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 age
#
# NameError: name 'age' is not defined

# %%
a=10
b=20
c='ubaid'
d=40

# %%
name='ali'
age=18
weight_kg=55
height_feet=5.6

# %%
name
# Out:
# 'ali'

# %%
weight_kg
# Out:
# 55

# %%
height_feet
# Out:
# 5.6

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(weight_kg)
# Out:
# int

# %%
type(height_feet)
# Out:
# float

# %% [markdown]
# # Variables Rules
#
#     1 In varaible name can not be used space
#     2 In variable cannot be start with a number
#     3 In Variable cannot be used any python opeator
#     4 In Vaiable cannot be used any python reserved word

# %%
first name='hassan'
# Out:
#   Cell In[14], line 1
#     first name='hassan'
#           ^
# SyntaxError: invalid syntax

# %%
first_name='hassan'

# %%
first_name
# Out:
# 'hassan'

# %%
1st_class='python'
# Out:
#   Cell In[17], line 1
#     1st_class='python'
#     ^
# SyntaxError: invalid decimal literal

# %%
class_1='python'

# %%
class_1
# Out:
# 'python'

# %%
first+name='jamshed'
# Out:
#   Cell In[20], line 1
#     first+name='jamshed'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
job-tittle='Data Scientist'
# Out:
#   Cell In[21], line 1
#     job-tittle='Data Scientist'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
class='matric'
# Out:
#   Cell In[22], line 1
#     class='matric'
#          ^
# SyntaxError: invalid syntax

# %%
if=28
# Out:
#   Cell In[23], line 1
#     if=28
#       ^
# SyntaxError: invalid syntax

# %%
else=28
# Out:
#   Cell In[24], line 1
#     else=28
#     ^
# SyntaxError: invalid syntax

# %%
fisrt_name=True

# %%
fisrt_name
# Out:
# True

# %%
# Update Variables

# %%
age=18
age=27

# %%
print(age)
# Out:
# 27

# %%
name='Hussain'
course='python'
roll_no=37373

# %%
name
# Out:
# 'Hussain'

# %%
course
# Out:
# 'python'

# %%
roll_no
# Out:
# 37373

# %%
name='hassan'

# %%
name
# Out:
# 'hassan'

# %%
course
# Out:
# 'python'

# %%
course='cyber'

# %%
course
# Out:
# 'cyber'

# %%
id(name)
# Out:
# 1552348527472

# %%
id(course)
# Out:
# 1552349872560

# %%
id(age)
# Out:
# 140734632277736

# %%
num_1=10
num_2=66

# %%
num_1
# Out:
# 10

# %%
num_2
# Out:
# 66

# %%
result=num_1+num_2

# %%
result
# Out:
# 76

# %%
result
# Out:
# 76

# %%
var@=273
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 var@=273
#
# NameError: name 'var' is not defined

# %% [markdown]
# # Operators

# %% [markdown]
# # What is Operator
# #### operator is a special symbol or keyword used to perform operations on values and variables.The data that an operator acts upon is called an operand.

# %% [markdown]
# # There are many Types of Operators
#
#     Arithmetic operators
#
#     Assigments Operators
#
#     Camparision Opertors
#
#     Logical Operators
#
#     Membership Operators
#
#     Identity Operators
#
#     Bitwise Opeators

# %% [markdown]
# ## Arithmetic operators :
#
#
#     Addition  (+)
#
#     Subtraction (-)
#
#     Multiplication (*)
#
#     Division  (/)
#
#     Floor Division (//)
#
#     Exponent (**)
#
#     Remainder (%)

# %% [markdown]
# # Addidtion

# %%
66+77
# Out:
# 143

# %%
33+10+30
# Out:
# 73

# %%
num_1=22
num_2=33
num_3=12
num_4=22
num_5=10

# %%
num_1
# Out:
# 22

# %%
num_4
# Out:
# 22

# %%
data=num_1+num_2

# %%
data
# Out:
# 55

# %%
num_1+num_2+num_3+num_4+num_5
# Out:
# 99

# %%
num_3+num_2+num_1
# Out:
# 67

# %% [markdown]
# # Subtraction

# %%
num_1
# Out:
# 22

# %%
num_2
# Out:
# 33

# %%
num_3
# Out:
# 12

# %%
num_4
# Out:
# 22

# %%
num_2-num_1-num_4
# Out:
# -11

# %% [markdown]
# # Multiplication

# %%
a=10
b=30
c=3

# %%
a*c
# Out:
# 30

# %%
a*c*b
# Out:
# 900

# %%
# Prethensis

# %%
(a+b)*c
# Out:
# 120

# %%
total_cost=5000
total_revenue=7000

# %%
profit=total_revenue-total_cost

# %%
profit
# Out:
# 2000

# %%
n_1=10
n_2=20
n_3=40

# %%
(n_2-n_1)*3
# Out:
# 30

# %%
(n_2*n_1)-n_3
# Out:
# 160

# %%
Amount=50000

# %%
type(Amount*0.50)
# Out:
# float

# %%
10*2.2
# Out:
# 22.0

# %%
type(10*2)
# Out:
# int

# %%
student_1_salary=25000
student_2_salary=22000
student_3_salary=15000

# %%
(student_1_salary+student_2_salary+student_3_salary)/3
# Out:
# 20666.666666666668

# %% [markdown]
# # Division

# %%
student_1_salary
# Out:
# 25000

# %%
student_1_salary/2
# Out:
# 12500.0

# %%
type(student_2_salary/4)
# Out:
# float

# %%
a=10
b=20
c=15
d=40
e=2
f=4

# %%
a/e
# Out:
# 5.0

# %%
c/e
# Out:
# 7.5

# %% [markdown]
# # Floor Division

# %%
type(student_1_salary//2)
# Out:
# int

# %%
a//e
# Out:
# 5

# %%
c//e
# Out:
# 7

# %%
c///e
# Out:
#   Cell In[121], line 1
#     c///e
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Exponent

# %%
2**2
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
2**6
# Out:
# 64

# %%
2x2x2x2x2x2

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 15

# %%
d
# Out:
# 40

# %%
e
# Out:
# 2

# %%
f
# Out:
# 4

# %%
(e**f)**e
# Out:
# 256

# %%
(2**4)**2
# Out:
# 256

# %% [markdown]
# # Remainder  %

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
10%5
# Out:
# 0

# %%
20%10
# Out:
# 0
