# %% [markdown]
# Introduction to python

# %% [markdown]
# Python is a high language

# %%
Heading 


    # Heading 1 
    ## Heading 2
    ### Heading 3

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Introduction to Python

# %% [markdown]
# ### Introduction to Python

# %% [markdown]
# #### Introduction to Python

# %% [markdown]
# # Print Function

# %% [markdown]
# # what is print Function ?
#
# Print is a python bultin function thats print any object

# %%
print('my name is ubaid')
# Out:
# my name is ubaid

# %%
print('234')
# Out:
# 234

# %%
print(4.5)
# Out:
# 4.5

# %%
print('True')
# Out:
# True

# %% [markdown]
# ## MUltiple Values Print

# %%
print('ubaid','ali','hassan',80,sep='p',end=',')
print('ubaid','ali','hassan',80,sep='p')
# Out:
# ubaidpaliphassanp80,ubaidpaliphassanp80
