# %% [markdown]
# # Opeartors

# %% [markdown]
# # There are many Types of Operators
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# # Camparsion Operators   >>>>>  True| False
#
#     Greater Than  (>)
#
#     Less Than (<)
#
#     Equal To (==)
#
#     Not Equal To (!=)
#
#     Greater Than Equal To (>=)
#
#     Less Than Equal To (<=)

# %% [markdown]
# ## Greater Than

# %%
a=10
b=3

# %%
a>b
# Out:
# True

# %%
b>a
# Out:
# False

# %%
99>77
# Out:
# True

# %%
44>33
# Out:
# True

# %%
90>100
# Out:
# False

# %%
100>100
# Out:
# False

# %%
a>3
# Out:
# True

# %%
name='ali 5'

# %%
name>3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name>3
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
10>9
# Out:
# True

# %%
11>10
# Out:
# True

# %% [markdown]
# ## Less Than  (<)

# %%
100<99
# Out:
# False

# %%
20<21
# Out:
# True

# %%
35<45
# Out:
# True

# %%
888<887
# Out:
# False

# %%
42<43
# Out:
# True

# %%
num_1=88
num_2=44
num_3=33
num_4=12
num_5=44

# %%
num_1<num_2
# Out:
# False

# %%
num_3<num_1
# Out:
# True

# %%
num_4<num_5
# Out:
# True

# %%
44.2<33.2
# Out:
# False

# %%
44.3<44.2
# Out:
# False

# %%
9.99999<9.99998
# Out:
# False

# %%
int(9.99999)
# Out:
# 9

# %%
int(9.99998)
# Out:
# 9

# %%
9<9
# Out:
# False

# %% [markdown]
# # Equal To (==)

# %%
99==76
# Out:
# False

# %%
99==101
# Out:
# False

# %%
105==105
# Out:
# True

# %%
student_1=' ali'
student_2='hassan'
student_3='ali'

# %%
student_1==student_2
# Out:
# False

# %%
student_1==student_3
# Out:
# False

# %%
99.998==96.4556
# Out:
# False

# %%
55.4443==55.4442
# Out:
# False

# %%
int(55.4443)==int(55.4442)
# Out:
# True

# %%
True==False
# Out:
# False

# %%
False==False
# Out:
# True

# %% [markdown]
# # Not Equal To (!=)

# %%
88!=77
# Out:
# True

# %%
44!=44
# Out:
# False

# %%
33!=22!=33
# Out:
# True

# %%
True>3
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
False!=0
# Out:
# False

# %%
4!=4
# Out:
# False

# %%
'ali'>'ali'
# Out:
# False

# %%
# Akeys Codes

# %%
ord('a')
# Out:
# 97

# %%
ord('l')
# Out:
# 108

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('l')
# Out:
# 108

# %%
ord('i')
# Out:
# 105

# %%
97108105>97108105
# Out:
# False

# %%
'hassan'<'ubaid'
# Out:
# True

# %%
ord('h')
# Out:
# 104

# %%
ord('a')
# Out:
# 97

# %%
ord('s')
# Out:
# 115

# %%
ord('n')
# Out:
# 110

# %%
ord('u')
# Out:
# 117

# %%
ord('b')
# Out:
# 98

# %%
ord('i')
# Out:
# 105

# %%
ord('d')
# Out:
# 100

# %%
'hassan'<'ubaid'
# Out:
# True

# %%
Hassan                      ubaid
1049711511597110           1179897105100

# %%
1049711511597110<1179897105100
# Out:
# False

# %%
ord('ubaid')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 ord('ubaid')
#
# TypeError: ord() expected a character, but string of length 5 found

# %%
'nhs'>'hsc'
# Out:
# True

# %%
ord('n')
# Out:
# 110

# %%
ord('h')
# Out:
# 104

# %%
ord('s')
# Out:
# 115

# %%
ord('c')
# Out:
# 99

# %%
110104115>10411599
# Out:
# True

# %%
'hassan'<'ubaid'
# Out:
# True

# %%
hassan >>>>   1049711511597110

ubaid >>>>> 1179897105100

# %%
1049711597110<1179897105100
# Out:
# True

# %% [markdown]
# ## Greater Than Equal To (>=)

# %%
99>99
# Out:
# False

# %%
99>=99
# Out:
# True

# %%
99>=101
# Out:
# False

# %%
333>=299
# Out:
# True

# %%
44>=22
# Out:
# True

# %%
33>33
# Out:
# False

# %%
33>=33
# Out:
# True

# %%
'h'>='y'
# Out:
# False

# %%
ord('h')
# Out:
# 104

# %%
ord('y')
# Out:
# 121

# %%
104>=121
# Out:
# False

# %%
True>=False
# Out:
# True

# %% [markdown]
# # Less Than Equal To (<=)

# %%
55<=77
# Out:
# True

# %%
88<=87
# Out:
# False

# %%
88<=89
# Out:
# True

# %%
66<=66
# Out:
# True

# %% [markdown]
# # Logical Operators
#
#     and
#
#     or
#
#     not

# %%
# And

# %%
age=18
salary=25000

# %%
age>18
# Out:
# False

# %%
salary>20000
# Out:
# True

# %%
age>18 and salary>20000
# Out:
# False

# %% [markdown]
# # And Rules
#
#     1st condition                  2nd Condtion                     And
#
#     True                             False                          False
#
#     False                            True                          False
#
#     True                            True                           True
#
#     False                           False                          False

# %%
age
# Out:
# 18

# %%
salary
# Out:
# 25000

# %%
name='hassan'

# %%
name
# Out:
# 'hassan'

# %%
age
# Out:
# 18

# %%
salary
# Out:
# 25000

# %%
name=='hassan'
# Out:
# True

# %%
age>25
# Out:
# False

# %%
salary>25000
# Out:
# False

# %%
name=='hassan' and  age>25 and salary>25000
# Out:
# False

# %%
name=='hassan' and  age>12 and salary>23000
# Out:
# True

# %%
name=='ubaid' and  age>70 and salary>50000
# Out:
# False

# %%
name
# Out:
# 'hassan'

# %%
age
# Out:
# 18

# %%
salary
# Out:
# 25000

# %%
age>18
# Out:
# False

# %%
1st condtion                        2nd                              3rd 
name is equal to hassan          age is greater than 18            salary is greater than 25000

# %%
name=='hassan'
# Out:
# True

# %%
age>18
# Out:
# False

# %%
salary>25000
# Out:
# False

# %%
And >>>>>  All are True 


1st condition           2nd Condition     And Output

True                      False            False

False                     True             False

True                     True             True

False                    False            False

# %%
name=='hassan' and age>18 and salary>25000
# Out:
# False

# %%
name=='hassan'
# Out:
# True

# %%
age>12
# Out:
# True

# %%
salary>18000
# Out:
# True

# %%
job_role='data scientist'

# %%
job_role=='web developer'
# Out:
# False

# %%
name=='hassan' and age>12 and salary>18000 and job_role=='web developer'
# Out:
# False

# %% [markdown]
# # OR
#
#     1st_condtion           2nd_condition        3rd_condtion           OR_Output
#
#     True                    False                 False                 True
#
#     False                   False                 True                  True
#
#     True                    True                  True                  True
#
#     False                   False                 False                 False

# %%
product_name='laptop'
ram_gb=16
processor='i5'
generation='7Gen'
ssd_gb=512
price=45000

# %%
1 Student

product >>>>  laptop
Ram >>>>>>> 8gb

processor >>>>>  i5

Genration >>>>> 5

ssd >>>>> 256


price >>>>>>>   30000

# %%
product_name=='laptop' or ram_gb==8 or processor=='i5' or generation=='5Gen' or ssd_gb==256 or price<30000
# Out:
# True

# %%
|
