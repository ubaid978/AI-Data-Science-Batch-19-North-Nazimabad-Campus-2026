# %% [markdown]
# # There are many Types of Operators
#     Arithmetic operators
#
#     Camparsion Operators
#
#     Assignment Operators
#
#     Logical Operators
#
#     Identity Operator
#
#     Membership Operator
#
#     Bitwise Operators

# %% [markdown]
# ## Logical Operators   >>>>>>>   True | False
#
#
#     and
#
#     or
#
#     not

# %% [markdown]
# ### And
#
#     its all conditions are true

# %%
name='hassan'
age=18
height=5.5
weight=60.2

# %%
age >>> 25       height >>>6  weight >>>>50     >>>>> Handsome

# %%
age>25
# Out:
# False

# %%
height>6
# Out:
# False

# %%
weight<=50
# Out:
# False

# %%
age>25 and height>6 and weight<=50
# Out:
# False

# %%
person_2_name='ayan'
person_2_age=27
person_2_height_feet=6.6
person_2_weight_kg=55.3

# %%
person_2_age>25
# Out:
# True

# %%
person_2_height_feet>6
# Out:
# True

# %%
person_2_weight_kg<=50
# Out:
# False

# %%
person_2_age>25 and person_2_height_feet>6 and person_2_weight_kg<=50
# Out:
# False

# %% [markdown]
# And
#
#
#     condition 1                       Condition 2                  And Output
#
#
#     True                               False                        False
#
#
#     False                              True                         False
#
#
#     False                               False                       False
#
#
#     True                                True                        True

# %% [markdown]
# ## or
#
#     only one are True
#
#
#     Condition 1                              Condition 2             OR Output
#
#
#     True                                      False                   True
#
#
#     False                                     True                     True
#
#
#     True                                      True                     True
#
#     False                                     False                    False

# %%
student_1_name='hussain'
age=25
qulification='matric'
course='Ai'

# %%
AI  >>>>>

age  >>>>>> 18 greater than

qulification   >>> intermidiate

# %%
age>=18
# Out:
# True

# %%
qulification=='intermidiate'
# Out:
# False

# %%
age>=18 or qulification=='intermidiate'
# Out:
# True

# %%
student_1_name='hussain'
age=25
qulification='matric'
card_hy=True
course='Ai'

# %%
age >>>>>  18  card hy >>> True >>>>> qulification >>>>  matric

# %%
age>18
# Out:
# True

# %%
card_hy==True
# Out:
# True

# %%
qulification='intermidiate'

# %%
qulification
# Out:
# 'intermidiate'

# %%
card_hy=False

# %%
age>=18 and card_hy==True or qulification=='matric'
# Out:
# False

# %% [markdown]
# ## not
#
#     Condition reverse

# %%
not True
# Out:
# False

# %%
not True
# Out:
# False

# %%
not age>30
# Out:
# True

# %%
not name=='ali'
# Out:
# True

# %%
student_1_name='hussain'
age=25
qulification='matric'
card_hy=True
course='Ai'

# %%
age >>>>  <30    qulification not equal matric       card hy >> True  >>>>> course not equal to AI

# %%
not age>30
# Out:
# True

# %%
not qulification=='matric'
# Out:
# False

# %%
not card_hy==False
# Out:
# True

# %%
not course=='Ai'
# Out:
# False

# %%
not age>30 and not card_hy==False or not qulification=='matric' or not course=='Ai'
# Out:
# True

# %%
age=18

# %%
isinstance(age,str)
# Out:
# False

# %%
isinstance(age,int)
# Out:
# True

# %%
type(age)
# Out:
# int

# %%
name='nasir'

# %%
isinstance(name,str)
# Out:
# True

# %%
isinstance(name,float)
# Out:
# False

# %% [markdown]
# ## Truthy  and Falsy
#
#      Every Valid value are Truty

# %%
8 and 9
# Out:
# 9

# %%
bool(8)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(11)
# Out:
# True

# %%
bool('ali')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(-6)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool('None')
# Out:
# True

# %%
bool('undefind')
# Out:
# True

# %%
bool(28.644)
# Out:
# True

# %%
bool(0.000001)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
8 and 10
# Out:
# 10

# %%
0 and 11
# Out:
# 0

# %%
'ali' and 'ubaid'
# Out:
# 'ubaid'

# %%
'ali' or 'ubaid'
# Out:
# 'ali'

# %%
'ubaid' and 'ali'
# Out:
# 'ali'

# %%
'' or 'hassan'
# Out:
# 'hassan'

# %%
'' or ''
# Out:
# ''

# %%
not '' or 'hassan'
# Out:
# True

# %%
[] and 88
# Out:
# []

# %%
88 and 99 or 0
# Out:
# 99

# %%
x = -100
from math import sqrt

# %%
x > 0 and sqrt(x)
# Out:
# False

# %%
x > 0 or sqrt(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 x > 0 or sqrt(x)
#
# ValueError: math domain error

# %%
1 + 2 ** 3 * 4
# Out:
# 33
